# %% [markdown]
# # Day5 Functions

# %%
def comp(a,b):
    if(a>b):
        return a
    return b

def comp2(a,b):
    if(a>b):
        print(a)
    else:
        print(b)
        
def data():
    return 3.1456567

def greet():
    print("halo")

v1=data()    
v2=data()

# %%
#write a function to print a multiplication table by accepting the number

def table(num):
    for i in range(1,11):
        print(f"{num} x {i}={num*i}")
    print()


table(2)
table(3)
table(5)
