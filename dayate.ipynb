# %%
def paper10(n):
    c =1     
    for i in range(n*2):
        for j in range(n):
            if((i-j)>=0 and i<n-1):
                print(i+1+-j,end=" ")
            elif((i+j)<n*2-2 and i>=n-1):
                print((n+n-i-2)-j,end=" ")
            else:
                print(" ",end=" ")
                        
        print()

paper10(5)




# 1
# 2 1
# 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1
# Out:
# 1
# 2 1
# 3 2 1
# 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1

# %%
def paper8(n):
    c=1
    for i in range(n):
        for j in range(n):
            if((i-j)>=0):
            # if(i>=0):
                print((i+1) + n*j - (j*(j+1))//2,end=" ")
                # print(c,end=" ")
                
                
            else:
                print(" ",end=" ")
            # c+=1
        print()

paper8(5)
paper8(6)


# 1
# 2 6
# 3 7 10
# 4 8 11 13
# 5 9 12 14 15
# Out:
# 1
# 2 6
# 3 7 10
# 4 8 11 13
# 5 9 12 14 15
# 1
# 2 7
# 3 8 12
# 4 9 13 16
# 5 10 14 17 19
# 6 11 15 18 20 21
